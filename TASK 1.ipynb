# %%
import numpy as np
import pandas as pd


import os
for dirname, _, filenames in os.walk("/content/archive (1).zip"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       5 import os
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import re
with open("/content/aspell.txt", "r") as f:
    lines = f.readlines()
    words = []
    for line in lines:
        words += re.findall(r'\w+', line.lower())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import re
# ----> 2 with open("/content/aspell.txt", "r") as f:
#       3     lines = f.readlines()
#       4     words = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/aspell.txt'

# %%
import re
with open("/content/big.txt", "r") as f:
    lines = f.readlines()
    words = []
    for line in lines:
        words += re.findall(r'\w+', line.lower())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import re
# ----> 2 with open("/content/big.txt", "r") as f:
#       3     lines = f.readlines()
#       4     words = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/big.txt'

# %%
import re
with open("/content/birkbeck.txt", "r") as f:
    lines = f.readlines()
    words = []
    for line in lines:
        words += re.findall(r'\w+', line.lower())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import re
# ----> 2 with open("/content/birkbeck.txt", "r") as f:
#       3     lines = f.readlines()
#       4     words = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/birkbeck.txt'

# %%
import re
with open("/content/spell-testset1.txt", "r") as f:
    lines = f.readlines()
    words = []
    for line in lines:
        words += re.findall(r'\w+', line.lower())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import re
# ----> 2 with open("/content/spell-testset1.txt", "r") as f:
#       3     lines = f.readlines()
#       4     words = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/spell-testset1.txt'

# %%
import re
with open("/content/spell-testset2.txt", "r") as f:
    lines = f.readlines()
    words = []
    for line in lines:
        words += re.findall(r'\w+', line.lower())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import re
# ----> 2 with open("/content/spell-testset2.txt", "r") as f:
#       3     lines = f.readlines()
#       4     words = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/spell-testset2.txt'

# %%
import re
with open("/content/wikipedia.txt", "r") as f:
    lines = f.readlines()
    words = []
    for line in lines:
        words += re.findall(r'\w+', line.lower())

# %%
print(words[0:10])
# Out:
# ['apennines', 'apenines', 'appenines', 'athenian', 'athenean', 'athenians', 'atheneans', 'bernoulli', 'bernouilli', 'blitzkrieg']

# %%
print(f'total words in text file is {len(words)}')
# Out:
# total words in text file is 4388

# %%
vocabulary = set(words)
print(f"there are {len(vocabulary)} in vocabulary")
# Out:
# there are 4155 in vocabulary

# %%
from collections import Counter
word_count=Counter(words)

# %%
word_count['a']
# Out:
# 0

# %%
total_words=sum(word_count.values())
total_words
# Out:
# 4388

# %%
word_probabilities = {word: word_count[word] / total_words for word in word_count.keys()}

# %%
def split_word(word):
    return [(word[:i], word[i:]) for i in range(len(word) + 1)]
split_word('jatin')
# Out:
# [('', 'jatin'),
#  ('j', 'atin'),
#  ('ja', 'tin'),
#  ('jat', 'in'),
#  ('jati', 'n'),
#  ('jatin', '')]

# %%
def delete_word(word):
    return [l + r[1:] for l,r in split_word(word) if r]
delete_word('jatin')
# Out:
# ['atin', 'jtin', 'jain', 'jatn', 'jati']

# %%
def swap_word(word):
    return [l + r[1] + r[0] + r[2:] for l, r in split_word(word) if len(r)>1]
swap_word('jatin')
# Out:
# ['ajtin', 'jtain', 'jaitn', 'jatni']

# %%
import string
def replace_word(word):
    letters = string.ascii_lowercase
    return [l + c + r[1:] for l, r in split_word(word) if r for c in letters]
replace_word('jatin')
# Out:
# ['aatin',
#  'batin',
#  'catin',
#  'datin',
#  'eatin',
#  'fatin',
#  'gatin',
#  'hatin',
#  'iatin',
#  'jatin',
#  'katin',
#  'latin',
#  'matin',
#  'natin',
#  'oatin',
#  'patin',
#  'qatin',
#  'ratin',
#  'satin',
#  'tatin',
#  'uatin',
#  'vatin',
#  'watin',
#  'xatin',
#  'yatin',
#  'zatin',
#  'jatin',
#  'jbtin',
#  'jctin',
#  'jdtin',
#  'jetin',
#  'jftin',
#  'jgtin',
#  'jhtin',
#  'jitin',
#  'jjtin',
#  'jktin',
#  'jltin',
#  'jmtin',
#  'jntin',
#  'jotin',
#  'jptin',
#  'jqtin',
#  'jrtin',
#  'jstin',
#  'jttin',
#  'jutin',
#  'jvtin',
#  'jwtin',
#  'jxtin',
#  'jytin',
#  'jztin',
#  'jaain',
#  'jabin',
#  'jacin',
#  'jadin',
#  'jaein',
#  'jafin',
#  'jagin',
#  'jahin',
#  'jaiin',
#  'jajin',
#  'jakin',
#  'jalin',
#  'jamin',
#  'janin',
#  'jaoin',
#  'japin',
#  'jaqin',
#  'jarin',
#  'jasin',
#  'jatin',
#  'jauin',
#  'javin',
#  'jawin',
#  'jaxin',
#  'jayin',
#  'jazin',
#  'jatan',
#  'jatbn',
#  'jatcn',
#  'jatdn',
#  'jaten',
#  'jatfn',
#  'jatgn',
#  'jathn',
#  'jatin',
#  'jatjn',
#  'jatkn',
#  'jatln',
#  'jatmn',
#  'jatnn',
#  'jaton',
#  'jatpn',
#  'jatqn',
#  'jatrn',
#  'jatsn',
#  'jattn',
#  'jatun',
#  'jatvn',
#  'jatwn',
#  'jatxn',
#  'jatyn',
#  'jatzn',
#  'jatia',
#  'jatib',
#  'jatic',
#  'jatid',
#  'jatie',
#  'jatif',
#  'jatig',
#  'jatih',
#  'jatii',
#  'jatij',
#  'jatik',
#  'jatil',
#  'jatim',
#  'jatin',
#  'jatio',
#  'jatip',
#  'jatiq',
#  'jatir',
#  'jatis',
#  'jatit',
#  'jatiu',
#  'jativ',
#  'jatiw',
#  'jatix',
#  'jatiy',
#  'jatiz']

# %%
def insert_word(word):
    letters = string.ascii_lowercase
    return [l + c + r for l, r in split_word(word) for c in letters]
insert_word('jatin')
# Out:
# ['ajatin',
#  'bjatin',
#  'cjatin',
#  'djatin',
#  'ejatin',
#  'fjatin',
#  'gjatin',
#  'hjatin',
#  'ijatin',
#  'jjatin',
#  'kjatin',
#  'ljatin',
#  'mjatin',
#  'njatin',
#  'ojatin',
#  'pjatin',
#  'qjatin',
#  'rjatin',
#  'sjatin',
#  'tjatin',
#  'ujatin',
#  'vjatin',
#  'wjatin',
#  'xjatin',
#  'yjatin',
#  'zjatin',
#  'jaatin',
#  'jbatin',
#  'jcatin',
#  'jdatin',
#  'jeatin',
#  'jfatin',
#  'jgatin',
#  'jhatin',
#  'jiatin',
#  'jjatin',
#  'jkatin',
#  'jlatin',
#  'jmatin',
#  'jnatin',
#  'joatin',
#  'jpatin',
#  'jqatin',
#  'jratin',
#  'jsatin',
#  'jtatin',
#  'juatin',
#  'jvatin',
#  'jwatin',
#  'jxatin',
#  'jyatin',
#  'jzatin',
#  'jaatin',
#  'jabtin',
#  'jactin',
#  'jadtin',
#  'jaetin',
#  'jaftin',
#  'jagtin',
#  'jahtin',
#  'jaitin',
#  'jajtin',
#  'jaktin',
#  'jaltin',
#  'jamtin',
#  'jantin',
#  'jaotin',
#  'japtin',
#  'jaqtin',
#  'jartin',
#  'jastin',
#  'jattin',
#  'jautin',
#  'javtin',
#  'jawtin',
#  'jaxtin',
#  'jaytin',
#  'jaztin',
#  'jatain',
#  'jatbin',
#  'jatcin',
#  'jatdin',
#  'jatein',
#  'jatfin',
#  'jatgin',
#  'jathin',
#  'jatiin',
#  'jatjin',
#  'jatkin',
#  'jatlin',
#  'jatmin',
#  'jatnin',
#  'jatoin',
#  'jatpin',
#  'jatqin',
#  'jatrin',
#  'jatsin',
#  'jattin',
#  'jatuin',
#  'jatvin',
#  'jatwin',
#  'jatxin',
#  'jatyin',
#  'jatzin',
#  'jatian',
#  'jatibn',
#  'jaticn',
#  'jatidn',
#  'jatien',
#  'jatifn',
#  'jatign',
#  'jatihn',
#  'jatiin',
#  'jatijn',
#  'jatikn',
#  'jatiln',
#  'jatimn',
#  'jatinn',
#  'jation',
#  'jatipn',
#  'jatiqn',
#  'jatirn',
#  'jatisn',
#  'jatitn',
#  'jatiun',
#  'jativn',
#  'jatiwn',
#  'jatixn',
#  'jatiyn',
#  'jatizn',
#  'jatina',
#  'jatinb',
#  'jatinc',
#  'jatind',
#  'jatine',
#  'jatinf',
#  'jating',
#  'jatinh',
#  'jatini',
#  'jatinj',
#  'jatink',
#  'jatinl',
#  'jatinm',
#  'jatinn',
#  'jatino',
#  'jatinp',
#  'jatinq',
#  'jatinr',
#  'jatins',
#  'jatint',
#  'jatinu',
#  'jatinv',
#  'jatinw',
#  'jatinx',
#  'jatiny',
#  'jatinz']

# %%
def word_combinations(word):
    return set(delete_word(word) + swap_word(word) + replace_word(word) + insert_word(word))
word_combinations('jatin')
# Out:
# {'aatin',
#  'ajatin',
#  'ajtin',
#  'atin',
#  'batin',
#  'bjatin',
#  'catin',
#  'cjatin',
#  'datin',
#  'djatin',
#  'eatin',
#  'ejatin',
#  'fatin',
#  'fjatin',
#  'gatin',
#  'gjatin',
#  'hatin',
#  'hjatin',
#  'iatin',
#  'ijatin',
#  'jaain',
#  'jaatin',
#  'jabin',
#  'jabtin',
#  'jacin',
#  'jactin',
#  'jadin',
#  'jadtin',
#  'jaein',
#  'jaetin',
#  'jafin',
#  'jaftin',
#  'jagin',
#  'jagtin',
#  'jahin',
#  'jahtin',
#  'jaiin',
#  'jain',
#  'jaitin',
#  'jaitn',
#  'jajin',
#  'jajtin',
#  'jakin',
#  'jaktin',
#  'jalin',
#  'jaltin',
#  'jamin',
#  'jamtin',
#  'janin',
#  'jantin',
#  'jaoin',
#  'jaotin',
#  'japin',
#  'japtin',
#  'jaqin',
#  'jaqtin',
#  'jarin',
#  'jartin',
#  'jasin',
#  'jastin',
#  'jatain',
#  'jatan',
#  'jatbin',
#  'jatbn',
#  'jatcin',
#  'jatcn',
#  'jatdin',
#  'jatdn',
#  'jatein',
#  'jaten',
#  'jatfin',
#  'jatfn',
#  'jatgin',
#  'jatgn',
#  'jathin',
#  'jathn',
#  'jati',
#  'jatia',
#  'jatian',
#  'jatib',
#  'jatibn',
#  'jatic',
#  'jaticn',
#  'jatid',
#  'jatidn',
#  'jatie',
#  'jatien',
#  'jatif',
#  'jatifn',
#  'jatig',
#  'jatign',
#  'jatih',
#  'jatihn',
#  'jatii',
#  'jatiin',
#  'jatij',
#  'jatijn',
#  'jatik',
#  'jatikn',
#  'jatil',
#  'jatiln',
#  'jatim',
#  'jatimn',
#  'jatin',
#  'jatina',
#  'jatinb',
#  'jatinc',
#  'jatind',
#  'jatine',
#  'jatinf',
#  'jating',
#  'jatinh',
#  'jatini',
#  'jatinj',
#  'jatink',
#  'jatinl',
#  'jatinm',
#  'jatinn',
#  'jatino',
#  'jatinp',
#  'jatinq',
#  'jatinr',
#  'jatins',
#  'jatint',
#  'jatinu',
#  'jatinv',
#  'jatinw',
#  'jatinx',
#  'jatiny',
#  'jatinz',
#  'jatio',
#  'jation',
#  'jatip',
#  'jatipn',
#  'jatiq',
#  'jatiqn',
#  'jatir',
#  'jatirn',
#  'jatis',
#  'jatisn',
#  'jatit',
#  'jatitn',
#  'jatiu',
#  'jatiun',
#  'jativ',
#  'jativn',
#  'jatiw',
#  'jatiwn',
#  'jatix',
#  'jatixn',
#  'jatiy',
#  'jatiyn',
#  'jatiz',
#  'jatizn',
#  'jatjin',
#  'jatjn',
#  'jatkin',
#  'jatkn',
#  'jatlin',
#  'jatln',
#  'jatmin',
#  'jatmn',
#  'jatn',
#  'jatni',
#  'jatnin',
#  'jatnn',
#  'jatoin',
#  'jaton',
#  'jatpin',
#  'jatpn',
#  'jatqin',
#  'jatqn',
#  'jatrin',
#  'jatrn',
#  'jatsin',
#  'jatsn',
#  'jattin',
#  'jattn',
#  'jatuin',
#  'jatun',
#  'jatvin',
#  'jatvn',
#  'jatwin',
#  'jatwn',
#  'jatxin',
#  'jatxn',
#  'jatyin',
#  'jatyn',
#  'jatzin',
#  'jatzn',
#  'jauin',
#  'jautin',
#  'javin',
#  'javtin',
#  'jawin',
#  'jawtin',
#  'jaxin',
#  'jaxtin',
#  'jayin',
#  'jaytin',
#  'jazin',
#  'jaztin',
#  'jbatin',
#  'jbtin',
#  'jcatin',
#  'jctin',
#  'jdatin',
#  'jdtin',
#  'jeatin',
#  'jetin',
#  'jfatin',
#  'jftin',
#  'jgatin',
#  'jgtin',
#  'jhatin',
#  'jhtin',
#  'jiatin',
#  'jitin',
#  'jjatin',
#  'jjtin',
#  'jkatin',
#  'jktin',
#  'jlatin',
#  'jltin',
#  'jmatin',
#  'jmtin',
#  'jnatin',
#  'jntin',
#  'joatin',
#  'jotin',
#  'jpatin',
#  'jptin',
#  'jqatin',
#  'jqtin',
#  'jratin',
#  'jrtin',
#  'jsatin',
#  'jstin',
#  'jtain',
#  'jtatin',
#  'jtin',
#  'jttin',
#  'juatin',
#  'jutin',
#  'jvatin',
#  'jvtin',
#  'jwatin',
#  'jwtin',
#  'jxatin',
#  'jxtin',
#  'jyatin',
#  'jytin',
#  'jzatin',
#  'jztin',
#  'katin',
#  'kjatin',
#  'latin',
#  'ljatin',
#  'matin',
#  'mjatin',
#  'natin',
#  'njatin',
#  'oatin',
#  'ojatin',
#  'patin',
#  'pjatin',
#  'qatin',
#  'qjatin',
#  'ratin',
#  'rjatin',
#  'satin',
#  'sjatin',
#  'tatin',
#  'tjatin',
#  'uatin',
#  'ujatin',
#  'vatin',
#  'vjatin',
#  'watin',
#  'wjatin',
#  'xatin',
#  'xjatin',
#  'yatin',
#  'yjatin',
#  'zatin',
#  'zjatin'}

# %%
def all_word_combinations(word):
    return set(e2 for e1 in word_combinations(word) for e2 in word_combinations(e1))
all_word_combinations('jatin')
# Out:
# {'qaoin',
#  'jwaatin',
#  'jasik',
#  'jxxtin',
#  'jtaio',
#  'jakind',
#  'jahtinl',
#  'jatfinb',
#  'jaotbn',
#  'vaqin',
#  'jjratin',
#  'japtoin',
#  'jativun',
#  'jrtyin',
#  'laein',
#  'joatjn',
#  'pjatnin',
#  'batiwn',
#  'jaejin',
#  'jatoiy',
#  'natik',
#  'vjatn',
#  'jetinn',
#  'jabtij',
#  'jatqiyn',
#  'jatwil',
#  'jbatln',
#  'jeatinn',
#  'qkatin',
#  'jakivn',
#  'javtln',
#  'kjatinj',
#  'jatjnb',
#  'jaltia',
#  'jpatain',
#  'zjatifn',
#  'jawtni',
#  'jatitfn',
#  'jpamtin',
#  'watyn',
#  'jatinei',
#  'ijamtin',
#  'ajtii',
#  'ijatian',
#  'jiutin',
#  'jatj',
#  'jbatis',
#  'jhaoin',
#  'kjlatin',
#  'rjatfin',
#  'sjatind',
#  'jauln',
#  'jatiine',
#  'jadqtin',
#  'jahiq',
#  'jetinr',
#  'ujqatin',
#  'jqatinu',
#  'jiatink',
#  'yjaticn',
#  'jwarin',
#  'batidn',
#  'jarinj',
#  'jatwinx',
#  'jabgin',
#  'rapin',
#  'jzaiin',
#  'jaxinr',
#  'jganin',
#  'jvamin',
#  'jartnn',
#  'jtaptin',
#  'wsatin',
#  'jatmmn',
#  'jatinke',
#  'jatfdn',
#  'jaytik',
#  'jhthn',
#  'jawirn',
#  'jatinpv',
#  'jntcin',
#  'jajwin',
#  'jacxn',
#  'tjavin',
#  'jxatiin',
#  'jwtzin',
#  'jatinpz',
#  'jatin',
#  'jzavin',
#  'habtin',
#  'jatirb',
#  'jatiys',
#  'jatinyz',
#  'jamtqin',
#  'jgatpin',
#  'tuatin',
#  'cativ',
#  'jxatii',
#  'jatinxr',
#  'cafin',
#  'jwhtin',
#  'jatvinj',
#  'zatqin',
#  'japiun',
#  'jakjn',
#  'jratil',
#  'iatzn',
#  'jrtiin',
#  'wstin',
#  'jazgtin',
#  'fatinj',
#  'batpn',
#  'jbthn',
#  'joatip',
#  'mdtin',
#  'javtiny',
#  'qjatix',
#  'jathon',
#  'jatlxin',
#  'jsatin',
#  'jaemin',
#  'jlaxtin',
#  'jtaain',
#  'djotin',
#  'jabind',
#  'jqztin',
#  'pjatint',
#  'jaqtini',
#  'daqin',
#  'jxtinw',
#  'jrthin',
#  'jawtln',
#  'jettn',
#  'vasin',
#  'satih',
#  'ljatein',
#  'jotitn',
#  'jateidn',
#  'jtatisn',
#  'rjation',
#  'peatin',
#  'jhaatin',
#  'jatiqjn',
#  'jatztn',
#  'jmti',
#  'jjaqin',
#  'jnyatin',
#  'ajatjn',
#  'jzaltin',
#  'jdtiun',
#  'jatira',
#  'juatyin',
#  'eaptin',
#  'jathy',
#  'jatinos',
#  'jatiob',
#  'jatipa',
#  'jatise',
#  'jhaktin',
#  'cjain',
#  'jawi',
#  'jsabtin',
#  'jatinls',
#  'jxtibn',
#  'jetind',
#  'patinu',
#  'jaltij',
#  'xjatif',
#  'jaxih',
#  'jaltipn',
#  'jatiko',
#  'batie',
#  'jltbn',
#  'jgtie',
#  'jajiq',
#  'jwaiin',
#  'jaqiy',
#  'jaqticn',
#  'jsabin',
#  'jatsij',
#  'jamtinl',
#  'jaticgn',
#  'pjatn',
#  'jatki',
#  'jatuny',
#  'jcmatin',
#  'jaetiy',
#  'jmathn',
#  'jmatoin',
#  'uatkn',
#  'jaksin',
#  'jarign',
#  'cljatin',
#  'jatkian',
#  'jatbin',
#  'oaatin',
#  'catiw',
#  'xxtin',
#  'jgatoin',
#  'jytien',
#  'jraqin',
#  'jatghn',
#  'jtaimn',
#  'taiin',
#  'jntnin',
#  'dcatin',
#  'jaxitin',
#  'jatixhn',
#  'jatiygn',
#  'jituin',
#  'jgtij',
#  'jdatif',
#  'jaytiw',
#  'mjjatin',
#  'fjatinj',
#  'xjatig',
#  'hjatpin',
#  'jatimw',
#  'jabtsn',
#  'jmaxin',
#  'jatikj',
#  'jmtmn',
#  'jaczin',
#  'jwctin',
#  'jatmizn',
#  'jztian',
#  'kbtin',
#  'latino',
#  'njatun',
#  'jetsin',
#  'jatianl',
#  'jaqtig',
#  'ajatinr',
#  'jatrinm',
#  'jatima',
#  'yajin',
#  'jttinn',
#  'jamtuin',
#  'jhtiwn',
#  'ujatrn',
#  'jnaticn',
#  'jbatil',
#  'jatiwh',
#  'ljytin',
#  'jyzatin',
#  'gjatzin',
#  'jastimn',
#  'jatlivn',
#  'jawimn',
#  'janiy',
#  'jatincf',
#  'jatpu',
#  'jauiny',
#  'jltic',
#  'jatgizn',
#  'jatiknu',
#  'kxatin',
#  'jaltixn',
#  'jbztin',
#  'jawtinp',
#  'japtwin',
#  'qjatzin',
#  'jatianr',
#  'gatinw',
#  'jqin',
#  'jyatic',
#  'satjn',
#  'jhtipn',
#  'jaytiz',
#  'jatwid',
#  'hjatnin',
#  'lrjatin',
#  'jatdina',
#  'jatjf',
#  'jatiytn',
#  'jatfwin',
#  'kagin',
#  'jfkatin',
#  'djatun',
#  'jatigm',
#  'raetin',
#  'jaqtdin',
#  'jyatbn',
#  'javtit',
#  'gatina',
#  'jatziw',
#  'jatbgin',
#  'wjatrin',
#  'jkatino',
#  'nalin',
#  'jatnio',
#  'zjatikn',
#  'jalizn',
#  'jatdicn',
#  'jatiyu',
#  'gjatiyn',
#  'aatimn',
#  'latgin',
#  'jatgnk',
#  'patid',
#  'jmhin',
#  'jatrinp',
#  'jvtina',
#  'jajpin',
#  'jatlzn',
#  'jatifv',
#  'jateid',
#  'juqin',
#  'zaqtin',
#  'jpatln',
#  'jlatiu',
#  'jfctin',
#  'jatyihn',
#  'cjyatin',
#  'jatqhn',
#  'jvgatin',
#  'jaetinq',
#  'jatfih',
#  'jgtink',
#  'jatrinx',
#  'cjatimn',
#  'jutind',
#  'jatinpt',
#  'jgatim',
#  'vatib',
#  'juftin',
#  'jatut',
#  'ajatim',
#  'jaiiw',
#  'ntjatin',
#  'jtatrin',
#  'jaiitn',
#  'fjavin',
#  'kalin',
#  'jatpl',
#  'javtii',
#  'hjaticn',
#  'jeztin',
#  'jlatins',
#  'jqatwn',
#  'jajton',
#  'jatlinw',
#  'jatninu',
#  'jatqln',
#  'tajtin',
#  'yatiy',
#  'jatainx',
#  'jaoipn',
#  'jhtixn',
#  'jtatiny',
#  'jbtie',
#  'jaticm',
#  'jatqiy',
#  'ljatxn',
#  'gnjatin',
#  'hjyatin',
#  'jjtinx',
#  'jategin',
#  'tsatin',
#  'jaetind',
#  'jarytin',
#  'keatin',
#  'jatal',
#  'jhtinn',
#  'jttpn',
#  'jacig',
#  'jftio',
#  'jatcbin',
#  'jajmtin',
#  'qjatbn',
#  'djutin',
#  'jrmatin',
#  'jaqid',
#  'yjutin',
#  'vjatinu',
#  'jajiun',
#  'jatppn',
#  'matihn',
#  'lxatin',
#  'jxcatin',
#  'jratuin',
#  'jaivin',
#  'fatmn',
#  'jafain',
#  'ijatnin',
#  'kaytin',
#  'katvin',
#  'jadxtin',
#  'jbauin',
#  'juaxin',
#  'jami',
#  'catig',
#  'jatnein',
#  'jutnin',
#  'jattr',
#  'jatlint',
#  'fatix',
#  'jatiknk',
#  'jtatitn',
#  'jatnibn',
#  'laytin',
#  'yatic',
#  'jatliwn',
#  'joatinf',
#  'sjatiwn',
#  'jatinzi',
#  'mjatfn',
#  'jfatmn',
#  'ajatir',
#  'jatpiun',
#  'jvqin',
#  'jathmin',
#  'zkatin',
#  'jttnn',
#  'jatiyp',
#  'jafiny',
#  'jratcin',
#  'jasind',
#  'jvyin',
#  'jsiin',
#  'jacatin',
#  'jateinv',
#  'jatvins',
#  'jatyzin',
#  'jagtifn',
#  'watinh',
#  'jgthn',
#  'jdtrn',
#  'katon',
#  'jxtcn',
#  'waktin',
#  'vjazin',
#  'jtsatin',
#  'batyn',
#  'jbtyn',
#  'jagwn',
#  'jeafin',
#  'jyatiq',
#  'jttiu',
#  'jaztuin',
#  'jgajin',
#  'cjatiun',
#  'jaypin',
#  'jateen',
#  'jyarin',
#  'jatnink',
#  'jaykin',
#  'sjsatin',
#  'jatip',
#  'jytoin',
#  'jcazin',
#  'oaztin',
#  'jatido',
#  'jagtinu',
#  'jctiy',
#  'jmgtin',
#  'jbatinq',
#  'jatikzn',
#  'jaqtfin',
#  'jaqtic',
#  'ejutin',
#  'pjalin',
#  'jceatin',
#  'jmtian',
#  'jatsgn',
#  'jaftuin',
#  'jajibn',
#  'jrattn',
#  'juten',
#  'jaytin',
#  'batmin',
#  'jatikw',
#  'jamten',
#  'jancin',
#  'janan',
#  'uaxin',
#  'jaatiw',
#  'ytatin',
#  'jzatvin',
#  'zdjatin',
#  'rjrtin',
#  'jatidnb',
#  'jalinf',
#  'aacin',
#  'jatviun',
#  'jatninv',
#  'jatiypn',
#  'iatijn',
#  'jasiqn',
#  'jevin',
#  'jfaftin',
#  'tatdn',
#  'jkatifn',
#  'jaktio',
#  'jatais',
#  'jaoltin',
#  'jatinrt',
#  'jarctin',
#  'jczatin',
#  'vjatinh',
#  'jebatin',
#  'maltin',
#  'jaktsin',
#  'jafdtin',
#  'iatip',
#  'jaitinf',
#  'jatoipn',
#  'hjatij',
#  'ujamtin',
#  'jatinep',
#  'jauicn',
#  'jagbn',
#  'jatindb',
#  'janten',
#  'maqin',
#  'aaxtin',
#  'wjatinm',
#  'jaivtin',
#  'jaszn',
#  'fatik',
#  'qatip',
#  'jaovin',
#  'yjatinh',
#  'jabip',
#  'jamtgn',
#  'jaytiin',
#  'jaftan',
#  'ejatipn',
#  'jatiend',
#  'gjotin',
#  'jrthn',
#  'jiastin',
#  'jaqtid',
#  'kjatkn',
#  'ijautin',
#  'rjatcin',
#  'joavtin',
#  'jaltyin',
#  'ujahtin',
#  'jktih',
#  'japtij',
#  'datzin',
#  'jctiu',
#  'nattin',
#  'datiun',
#  'gjatnn',
#  'jatxib',
#  'jatgen',
#  'njftin',
#  'eating',
#  'jatilnx',
#  'zrtin',
#  'qjatsn',
#  'jjaxin',
#  'jaxjn',
#  'pjetin',
#  'jatsil',
#  'jatiind',
#  'jmtqn',
#  'ajatiu',
#  'ajatimn',
#  'jatziwn',
#  'jgatiz',
#  'qjatina',
#  'matmin',
#  'matvn',
#  'jaxtik',
#  'jatiknc',
#  'jatiea',
#  'tljatin',
#  'ujnatin',
#  'hjatiy',
#  'iatic',
#  'jrnin',
#  'jbtim',
#  'ttjatin',
#  'jatimv',
#  'batdn',
#  'atan',
#  'jxamtin',
#  'cjatzin',
#  'jitisn',
#  'jqatkn',
#  'mamtin',
#  'aaitin',
#  'jaytiv',
#  'jatxnt',
#  'jatgwn',
#  'djbtin',
#  'jaktit',
#  'jyvin',
#  'jaeinf',
#  'jetwin',
#  'jatlion',
#  'hamtin',
#  'jawih',
#  'jazutin',
#  'jatpinf',
#  'jatzj',
#  'jamtid',
#  'jyavtin',
#  'jaiitin',
#  'jaokn',
#  'jhytin',
#  'jbatiyn',
#  'jabtisn',
#  'jaxmtin',
#  'jatitnx',
#  'jatkiqn',
#  'jxtni',
#  'jauiwn',
#  'ziatin',
#  'jatke',
#  'jamtign',
#  'jattnq',
#  'jaqix',
#  'ijatbin',
#  'jsaftin',
#  'jiatgin',
#  'batxn',
#  'jatiwp',
#  'jytikn',
#  'jaxpn',
#  'jaatgn',
#  'bjatia',
#  'jatilna',
#  'bjatiin',
#  'jatpink',
#  'jauytin',
#  'jativc',
#  'vatrin',
#  'gatii',
#  'jatidfn',
#  'jtirn',
#  'jttie',
#  'jatwzn',
#  'jatttn',
#  'djatifn',
#  'uatil',
#  'jratzin',
#  'vaatin',
#  'jajtiln',
#  'xatiun',
#  'jatliln',
#  'qativ',
#  'qjatil',
#  'jaktinc',
#  'jettin',
#  'bjlatin',
#  'jaltino',
#  'jpttn',
#  'jaqyin',
#  'jptix',
#  'jatiniu',
#  'qjatizn',
#  'patrin',
#  'jxeatin',
#  'jatv',
#  'jaqinu',
#  'gjatjin',
#  'caetin',
#  'jaatib',
#  'zjatbn',
#  'bjatvn',
#  'iatinp',
#  'jatifnk',
#  'zatfin',
#  'djaptin',
#  'cjagin',
#  'jatbifn',
#  'javvtin',
#  'jczin',
#  'jnaton',
#  'jatdn',
#  'jaqtiwn',
#  'jaatikn',
#  'jahtin',
#  'jatinnn',
#  'njatid',
#  'jatiffn',
#  'jatxx',
#  'iatign',
#  'jabtign',
#  'janirn',
#  'jastidn',
#  'xatdn',
#  'xjatifn',
#  'jutino',
#  'jabttin',
#  'kjatiln',
#  'yatiq',
#  'jtainf',
#  'jacmin',
#  'jksatin',
#  'iatwin',
#  'jagen',
#  'gjatfn',
#  'jxabin',
#  'jautimn',
#  'jaasn',
#  'jaxtpn',
#  'jatinmo',
#  'jaitinl',
#  'eatinq',
#  'mxtin',
#  'jmatpin',
#  'zatpn',
#  'jatyien',
#  'ijatidn',
#  'jeathin',
#  'mgtin',
#  'gjitin',
#  'jataina',
#  'fjltin',
#  'jaituin',
#  'jetein',
#  'jatmiq',
#  'zatib',
#  'hatfin',
#  'jatinzk',
#  'mqjatin',
#  'jatkrn',
#  'vjatwn',
#  'jxtivn',
#  'jatqyin',
#  'yjasin',
#  'jaoinl',
#  'oatni',
#  'jatckin',
#  'tjati',
#  'jatilp',
#  'ajatiun',
#  'ojdatin',
#  'jaitns',
#  'jateivn',
#  'jbnatin',
#  'rjatzn',
#  'ajadtin',
#  'jatoii',
#  'jasthn',
#  'jazticn',
#  'jjbtin',
#  'xjatik',
#  'njatini',
#  'fjutin',
#  'wjacin',
#  'jattinp',
#  'nitin',
#  'jamidn',
#  'oatipn',
#  'ajxtin',
#  'yatiwn',
#  'jatgtin',
#  'tatiw',
#  'jatax',
#  'jatniz',
#  'paton',
#  'vatiw',
#  'jjtien',
#  'irjatin',
#  'jadmin',
#  'jathie',
#  'jmatino',
#  'ljqatin',
#  'jatwii',
#  'jatob',
#  'jratinm',
#  'jaotoin',
#  'jaltian',
#  'tjatijn',
#  'jetivn',
#  'jwtnin',
#  'jauein',
#  'jrautin',
#  'javihn',
#  'mjagin',
#  'jahtirn',
#  'jstn',
#  'jxathin',
#  'jkiin',
#  'zatnin',
#  'qjahtin',
#  'joting',
#  'jatisx',
#  'vjatisn',
#  'jahxn',
#  'jaoi',
#  'jrtic',
#  'tjgatin',
#  'ejatio',
#  'jatynh',
#  'batiny',
#  'jazixn',
#  'jtvatin',
#  'rjantin',
#  'ajtuin',
#  'jatidgn',
#  'jwtiz',
#  'jakiun',
#  'jujtin',
#  'jvtwin',
#  'xjagtin',
#  'jljin',
#  'batiln',
#  'fatinw',
#  'jakis',
#  'jatizmn',
#  'qatpn',
#  'ajtin',
#  'jayxtin',
#  'jnatih',
#  'jatibr',
#  'eatih',
#  'jaztpn',
#  'jiytin',
#  'jadtpin',
#  'jfttin',
#  'jpatinn',
#  'ejhtin',
#  'jjticn',
#  'jaxotin',
#  'jatioz',
#  'jnatwn',
#  'jxatgn',
#  'jaaxn',
#  'jautizn',
#  'jpatij',
#  'jqtion',
#  'jhtix',
#  'fjbatin',
#  'hjatiw',
#  'ljatcn',
#  'ojatic',
#  'jctiun',
#  'vjatinl',
#  'jatieny',
#  'yjatinr',
#  'jatijk',
#  'jiatign',
#  'oati',
#  'jjyin',
#  'sagtin',
#  'matpin',
#  'jutinq',
#  'jactiqn',
#  'jamtin',
#  'jwatfin',
#  'jraytin',
#  'jxatein',
#  'jajtiq',
#  'ratikn',
#  'jadtinn',
#  'jotifn',
#  'jatql',
#  'putin',
#  'atinq',
#  'kautin',
#  'jacthin',
#  'jatwnt',
#  'jatmb',
#  'latgn',
#  'hatine',
#  'eatins',
#  'ojatins',
#  'jtatiy',
#  'jauix',
#  'jptqin',
#  'jatfsin',
#  'jatginl',
#  'xathin',
#  'tjfatin',
#  'datib',
#  'jaxtrn',
#  'jatvf',
#  'jautine',
#  'jaetbn',
#  'jatxic',
#  'ybjatin',
#  'xjnatin',
#  'jptina',
#  'jntinw',
#  'jmtig',
#  'ejatcin',
#  'juatxin',
#  'awatin',
#  'eativ',
#  'jatpng',
#  'eabtin',
#  'jatinta',
#  'jatflin',
#  'ajatiny',
#  'gjatqin',
#  'jatibun',
#  'juatir',
#  'jastlin',
#  'vjatig',
#  'gatfn',
#  'jcartin',
#  'hjamin',
#  'japztin',
#  'jatijwn',
#  'jaoting',
#  'jmazin',
#  'jagijn',
#  'jatdun',
#  'djeatin',
#  'jaeiin',
#  'javtun',
#  'xjatiy',
#  'jcxin',
#  'jxdin',
#  'jatidng',
#  'jktiin',
#  'daftin',
#  'jnatfn',
#  'jatidne',
#  'jaoqn',
#  'ojatcn',
#  'japtdin',
#  'jagtein',
#  'jatxna',
#  'jgtqin',
#  'djattn',
#  'jfatinq',
#  'oftin',
#  'cjatiz',
#  'ajtino',
#  'jarid',
#  'ratyin',
#  'katii',
#  'joakin',
#  'ejatjin',
#  'xjatinv',
#  'jajian',
#  'jaaiun',
#  'jzazin',
#  'fgtin',
#  'jgatein',
#  'mtatin',
#  'jatinpw',
#  'jaztim',
#  'jdamtin',
#  'jmtinb',
#  'jkeatin',
#  'jmatzn',
#  'javftin',
#  'jmqatin',
#  'datiu',
#  'jmthin',
#  'jtatie',
#  'tjaqtin',
#  'jaitkin',
#  'sjatib',
#  'jatfit',
#  'jxtiu',
#  'jntinn',
#  'bastin',
#  'yjatyn',
#  'jaftdin',
#  'jatane',
#  'jatctin',
#  'jazinw',
#  'matwin',
#  'jatiogn',
#  'jaspin',
#  'jatiken',
#  'yatihn',
#  'jatirdn',
#  'jagitn',
#  'jatqini',
#  'eijatin',
#  'jabqin',
#  'jwtn',
#  'jabtiqn',
#  'jucin',
#  'jgti',
#  'jjatiny',
#  'jjtwin',
#  'jetig',
#  'jltiny',
#  'hagtin',
#  'jatinzw',
#  'jbastin',
#  'jatinnc',
#  'jaqtinv',
#  'jbtatin',
#  'qatxin',
#  'jhatein',
#  'yatinb',
#  'janrtin',
#  'paatin',
#  'uatzin',
#  'jftdn',
#  'hatinw',
#  'jadtinu',
#  'jlatidn',
#  'xjatir',
#  'ojatni',
#  'jatjion',
#  'ojatir',
#  ...}

# %%
def correct_spelling(word, vocabulary, word_probabilities):
    if word in vocabulary:
        print(f"{word} is already correctly spelled")
        return

    suggestions = word_combinations(word) or all_word_combinations(word) or [word]
    best_guesses = [w for w in suggestions if w in vocabulary]
    return [(w, word_probabilities[w]) for w in best_guesses]

# %%
correct_spelling('volcabulary',vocabulary,word_probabilities)
# Out:
# []

# %%
def generate_combinations(word):
    letters = string.ascii_lowercase
    splitword = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deleteword = [l + r[1:] for l,r in splitword if r]
    swapword = [l + r[1] + r[0] + r[2:] for l, r in splitword if len(r)>1]
    replaceword = [l + c + r[1:] for l, r in splitword if r for c in letters]
    insertword = [l + c + r for l, r in splitword for c in letters]

    return set(deleteword + swapword + replaceword + insertword)

# %%
generate_combinations('how')
# Out:
# {'ahow',
#  'aow',
#  'bhow',
#  'bow',
#  'chow',
#  'cow',
#  'dhow',
#  'dow',
#  'ehow',
#  'eow',
#  'fhow',
#  'fow',
#  'ghow',
#  'gow',
#  'haow',
#  'haw',
#  'hbow',
#  'hbw',
#  'hcow',
#  'hcw',
#  'hdow',
#  'hdw',
#  'heow',
#  'hew',
#  'hfow',
#  'hfw',
#  'hgow',
#  'hgw',
#  'hhow',
#  'hhw',
#  'hiow',
#  'hiw',
#  'hjow',
#  'hjw',
#  'hkow',
#  'hkw',
#  'hlow',
#  'hlw',
#  'hmow',
#  'hmw',
#  'hnow',
#  'hnw',
#  'ho',
#  'hoa',
#  'hoaw',
#  'hob',
#  'hobw',
#  'hoc',
#  'hocw',
#  'hod',
#  'hodw',
#  'hoe',
#  'hoew',
#  'hof',
#  'hofw',
#  'hog',
#  'hogw',
#  'hoh',
#  'hohw',
#  'hoi',
#  'hoiw',
#  'hoj',
#  'hojw',
#  'hok',
#  'hokw',
#  'hol',
#  'holw',
#  'hom',
#  'homw',
#  'hon',
#  'honw',
#  'hoo',
#  'hoow',
#  'hop',
#  'hopw',
#  'hoq',
#  'hoqw',
#  'hor',
#  'horw',
#  'hos',
#  'hosw',
#  'hot',
#  'hotw',
#  'hou',
#  'houw',
#  'hov',
#  'hovw',
#  'how',
#  'howa',
#  'howb',
#  'howc',
#  'howd',
#  'howe',
#  'howf',
#  'howg',
#  'howh',
#  'howi',
#  'howj',
#  'howk',
#  'howl',
#  'howm',
#  'hown',
#  'howo',
#  'howp',
#  'howq',
#  'howr',
#  'hows',
#  'howt',
#  'howu',
#  'howv',
#  'howw',
#  'howx',
#  'howy',
#  'howz',
#  'hox',
#  'hoxw',
#  'hoy',
#  'hoyw',
#  'hoz',
#  'hozw',
#  'hpow',
#  'hpw',
#  'hqow',
#  'hqw',
#  'hrow',
#  'hrw',
#  'hsow',
#  'hsw',
#  'htow',
#  'htw',
#  'huow',
#  'huw',
#  'hvow',
#  'hvw',
#  'hw',
#  'hwo',
#  'hwow',
#  'hww',
#  'hxow',
#  'hxw',
#  'hyow',
#  'hyw',
#  'hzow',
#  'hzw',
#  'ihow',
#  'iow',
#  'jhow',
#  'jow',
#  'khow',
#  'kow',
#  'lhow',
#  'low',
#  'mhow',
#  'mow',
#  'nhow',
#  'now',
#  'ohow',
#  'ohw',
#  'oow',
#  'ow',
#  'phow',
#  'pow',
#  'qhow',
#  'qow',
#  'rhow',
#  'row',
#  'show',
#  'sow',
#  'thow',
#  'tow',
#  'uhow',
#  'uow',
#  'vhow',
#  'vow',
#  'whow',
#  'wow',
#  'xhow',
#  'xow',
#  'yhow',
#  'yow',
#  'zhow',
#  'zow'}

# %%
def generate_all_combinations(word):
    return set(e2 for e1 in generate_combinations(word) for e2 in generate_combinations(e1))
generate_all_combinations('how')
# Out:
# {'hotww',
#  'nrw',
#  'hobaw',
#  'hodw',
#  'wown',
#  'hoqp',
#  'howcz',
#  'htou',
#  'hoiuw',
#  'hjov',
#  'howws',
#  'hqowo',
#  'hromw',
#  'hjew',
#  'qhxw',
#  'hfoa',
#  'hqjow',
#  'roew',
#  'nhbw',
#  'zjow',
#  'thdow',
#  'boyw',
#  'holx',
#  'qhoq',
#  'hsotw',
#  'uhowf',
#  'hogwn',
#  'houxw',
#  'howpg',
#  'howaq',
#  'yhaw',
#  'xcw',
#  'hlzow',
#  'phjw',
#  'puw',
#  'zhowm',
#  'homwn',
#  'hglow',
#  'hodjw',
#  'homdw',
#  'hootw',
#  'zod',
#  'howwm',
#  'hlocw',
#  'hooq',
#  'bhovw',
#  'dhopw',
#  'hkov',
#  'thocw',
#  'ehouw',
#  'hgkw',
#  'jhyw',
#  'hpew',
#  'kuhow',
#  'izhow',
#  'jkhow',
#  'xuw',
#  'hohwc',
#  'phnw',
#  'kww',
#  'wbhow',
#  'qhuow',
#  'hsodw',
#  'rhoaw',
#  'rhowd',
#  'ahsow',
#  'hopwk',
#  'holf',
#  'yvow',
#  'hjogw',
#  'vohow',
#  'hit',
#  'wxow',
#  'wowe',
#  'pphow',
#  'huxow',
#  'vowx',
#  'zhowt',
#  'itow',
#  'hcwe',
#  'qhown',
#  'howbe',
#  'hfwx',
#  'whonw',
#  'npw',
#  'hozjw',
#  'hxowe',
#  'hcoww',
#  'kokw',
#  'whojw',
#  'riow',
#  'hohkw',
#  'hogs',
#  'hozk',
#  'alow',
#  'hofwb',
#  'hgom',
#  'zos',
#  'jhox',
#  'cthow',
#  'vowb',
#  'dhsw',
#  'noow',
#  'ghoa',
#  'heh',
#  'hjsw',
#  'uhok',
#  'hongw',
#  'bpow',
#  'oowa',
#  'gowg',
#  'lowb',
#  'hfot',
#  'ehlw',
#  'jowp',
#  'hmew',
#  'dcow',
#  'hvb',
#  'hoiwu',
#  'homwj',
#  'ooww',
#  'hpaow',
#  'lhoqw',
#  'jhzw',
#  'fowl',
#  'hxsow',
#  'htovw',
#  'hkowb',
#  'hcrw',
#  'phnow',
#  'hyot',
#  'zdow',
#  'hou',
#  'qou',
#  'jowy',
#  'mowd',
#  'wzow',
#  'whkow',
#  'hef',
#  'hkowz',
#  'fhpow',
#  'powi',
#  'hxqw',
#  'hgoiw',
#  'myw',
#  'khog',
#  'mowb',
#  'zhyow',
#  'hjwc',
#  'holqw',
#  'ehos',
#  'ghowr',
#  'hbwc',
#  'bwo',
#  'hlwl',
#  'foa',
#  'hopgw',
#  'sqw',
#  'hrtow',
#  'haou',
#  'hewb',
#  'klow',
#  'mofw',
#  'hjaow',
#  'zosw',
#  'aho',
#  'qhowu',
#  'yhowx',
#  'phvow',
#  'hownx',
#  'heoi',
#  'to',
#  'ghowo',
#  'mopw',
#  'hvoi',
#  'hfwt',
#  'eobw',
#  'nhopw',
#  'hbdow',
#  'homz',
#  'htwb',
#  'nolw',
#  'dhowi',
#  'howzc',
#  'hovvw',
#  'mvw',
#  'phlw',
#  'hxxw',
#  'rew',
#  'hrxw',
#  'zowq',
#  'hyowe',
#  'hkoc',
#  'xhiow',
#  'ghxow',
#  'ufow',
#  'hdowg',
#  'hnw',
#  'hcou',
#  'bof',
#  'hkogw',
#  'hlorw',
#  'xdow',
#  'ehowh',
#  'hohew',
#  'hkoiw',
#  'iwo',
#  'hnl',
#  'houwr',
#  'khjw',
#  'tphow',
#  'jwhow',
#  'byw',
#  'hqgow',
#  'ehol',
#  'holwb',
#  'phwo',
#  'kw',
#  'zhcow',
#  'yolw',
#  'jhom',
#  'hmpw',
#  'qwow',
#  'nhoc',
#  'hgyw',
#  'fhowo',
#  'hioy',
#  'gowu',
#  'hokwu',
#  'hpotw',
#  'hvowj',
#  'zhox',
#  'rhxw',
#  'mzow',
#  'hdwc',
#  'howkr',
#  'hownj',
#  'xhovw',
#  'hzoo',
#  'cww',
#  'shopw',
#  'howre',
#  'uhoyw',
#  'hiows',
#  'nqow',
#  'iolw',
#  'hzorw',
#  'ztow',
#  'hoawd',
#  'howgl',
#  'iowr',
#  'hoxwz',
#  'adow',
#  'ithow',
#  'lhvow',
#  'horwq',
#  'poyw',
#  'ahoe',
#  'huowz',
#  'hoawo',
#  'vhtow',
#  'hbmow',
#  'hzvow',
#  'rovw',
#  'gogw',
#  'pmow',
#  'ixhow',
#  'uhoew',
#  'ohocw',
#  'ooiw',
#  'sol',
#  'holwi',
#  'qow',
#  'hsy',
#  'hxhw',
#  'yhou',
#  'vowz',
#  'qowq',
#  'hoca',
#  'howok',
#  'hjvow',
#  'homrw',
#  'hut',
#  'hbot',
#  'hofwh',
#  'huwp',
#  'ypw',
#  'jhlw',
#  'hofv',
#  'shzw',
#  'howss',
#  'hoiow',
#  'rhvow',
#  'soy',
#  'phovw',
#  'howqv',
#  'hoqu',
#  'qhowh',
#  'hjwr',
#  'howoj',
#  'hpyw',
#  'dxow',
#  'oxw',
#  'udhow',
#  'whowp',
#  'rowe',
#  'ihqw',
#  'hvwp',
#  'hcokw',
#  'phowm',
#  'ohxw',
#  'hfobw',
#  'hoxfw',
#  'chlow',
#  'achow',
#  'rqow',
#  'hdjw',
#  'hpopw',
#  'dhxow',
#  'hoawr',
#  'sfw',
#  'lbw',
#  'hdwg',
#  'kkhow',
#  'whoj',
#  'hoiwl',
#  'hoef',
#  'eouw',
#  'nhoaw',
#  'eghow',
#  'ohomw',
#  'xomw',
#  'ynw',
#  'xow',
#  'omw',
#  'ukow',
#  'hwom',
#  'nhaw',
#  'voow',
#  'htozw',
#  'quow',
#  'ihhow',
#  'hmvow',
#  'hpq',
#  'syow',
#  'luow',
#  'hjowg',
#  'hovww',
#  'howhw',
#  'mowf',
#  'vob',
#  'rqhow',
#  'hurow',
#  'hojwz',
#  'hcwa',
#  'howmi',
#  'bww',
#  'powp',
#  'hojwp',
#  'hoawt',
#  'gokw',
#  'mmhow',
#  'thoww',
#  'yhos',
#  'oahow',
#  'hwtw',
#  'hbowe',
#  'hoawz',
#  'yhok',
#  'hiwow',
#  'nhaow',
#  'hggw',
#  'howsb',
#  'weow',
#  'rhog',
#  'gghow',
#  'hpp',
#  'hboo',
#  'zhzw',
#  'xovw',
#  'hzdow',
#  'hud',
#  'cpow',
#  'noi',
#  'qowi',
#  'mhrow',
#  'hwv',
#  'elow',
#  'hovwi',
#  'hdu',
#  'hlgw',
#  'honwz',
#  'poj',
#  'uhfw',
#  'yopw',
#  'hpr',
#  'xhowm',
#  'hxk',
#  'hhowc',
#  'ihowq',
#  'kowa',
#  'iowk',
#  'chfow',
#  'sot',
#  'whowf',
#  'dhowx',
#  'tor',
#  'hgk',
#  'kthow',
#  'bdow',
#  'dhoew',
#  'nzw',
#  'homwg',
#  'hptw',
#  'hujow',
#  'lowl',
#  'hhjw',
#  'honzw',
#  'haowc',
#  'hfos',
#  'hohhw',
#  'howms',
#  'zhoqw',
#  'uovw',
#  'hhmw',
#  'iowv',
#  'hodm',
#  'hhocw',
#  'hpkw',
#  'hpowg',
#  'hey',
#  'hpcw',
#  'hgowj',
#  'sobw',
#  'hnowd',
#  'hzowd',
#  'hkow',
#  'uohow',
#  'gjw',
#  'mhoq',
#  'hoowb',
#  'thowu',
#  'hvowh',
#  'hopd',
#  'hxmow',
#  'qoy',
#  'uhjow',
#  'hocow',
#  'aowx',
#  'hbonw',
#  'qholw',
#  'howob',
#  'pof',
#  'xotw',
#  'zhowv',
#  'dowd',
#  'khowp',
#  'ihfw',
#  'homtw',
#  'konw',
#  'hfqow',
#  'cnw',
#  'hpodw',
#  'ioc',
#  'hhwm',
#  'fobw',
#  'dkow',
#  'eop',
#  'qwo',
#  'gew',
#  'uhob',
#  'whkw',
#  'hwhw',
#  'ipow',
#  'ioz',
#  'hyowo',
#  'howol',
#  'hoewl',
#  'hbdw',
#  'hwowo',
#  'ehoaw',
#  'hosyw',
#  'hour',
#  'hlox',
#  'howsa',
#  'howsn',
#  'howjm',
#  'chowh',
#  'kopw',
#  'kho',
#  'mhxw',
#  'hohh',
#  'uox',
#  'honiw',
#  'hjyw',
#  'eshow',
#  'zowz',
#  'dhvow',
#  'hvorw',
#  'hxot',
#  'vhop',
#  'gihow',
#  'mowg',
#  'jnw',
#  'doh',
#  'hugw',
#  'hoawn',
#  'htowc',
#  'hck',
#  'hmoc',
#  'uhowu',
#  'khowi',
#  'hiuw',
#  'houwe',
#  'dhiw',
#  'htu',
#  'howdr',
#  'hwowe',
#  'vhowy',
#  'hvowt',
#  'hjt',
#  'howuu',
#  'nosw',
#  'comw',
#  'kvhow',
#  'hxoew',
#  'hojwx',
#  'nxw',
#  'zbhow',
#  'phowi',
#  'hyws',
#  'ahonw',
#  'ymow',
#  'howed',
#  'hskw',
#  'mowt',
#  'hqz',
#  'horwt',
#  'hsws',
#  'hosz',
#  'hfowk',
#  'hxoh',
#  'hpwz',
#  'cowi',
#  'howhy',
#  'yfow',
#  'town',
#  'lbow',
#  'hlov',
#  'choww',
#  'hoio',
#  'howtq',
#  'roj',
#  'hku',
#  'hpou',
#  'fyw',
#  'hotr',
#  'howky',
#  'bhaow',
#  'thrw',
#  'vhdw',
#  'won',
#  'hokgw',
#  'oowu',
#  'xhoo',
#  'vhows',
#  'hopwr',
#  'hkoe',
#  'nhzw',
#  'ahowz',
#  'zhocw',
#  'thaw',
#  'vhlow',
#  'hqouw',
#  'whown',
#  'khkow',
#  'hspw',
#  'vhsow',
#  'rhowr',
#  'hdoj',
#  'hbpw',
#  'nhosw',
#  'fok',
#  'jhpow',
#  'jhoiw',
#  'howxg',
#  'hoyrw',
#  'ghotw',
#  'hva',
#  'ikhow',
#  'sdw',
#  'khowo',
#  'dmow',
#  'uhyw',
#  'hmom',
#  'qhoy',
#  'hsok',
#  'powj',
#  'chqw',
#  'peow',
#  'kol',
#  'hlowx',
#  'zhoh',
#  'fhowz',
#  'hadow',
#  'hbh',
#  'bkw',
#  'uhtow',
#  'boq',
#  'hfzw',
#  'hvmw',
#  'hotd',
#  'hmlow',
#  'xghow',
#  'ghoe',
#  'ahoww',
#  'hrotw',
#  'howvo',
#  'heor',
#  'haw',
#  'hsof',
#  'kgow',
#  'bhowu',
#  'hwwr',
#  'qocw',
#  'hotg',
#  'yhop',
#  'ahoq',
#  'ioww',
#  'hrohw',
#  'howuw',
#  'hjvw',
#  'hdowy',
#  'heovw',
#  'hoobw',
#  'howww',
#  'hwkow',
#  'hdouw',
#  'chowk',
#  'avow',
#  'hgwd',
#  'toiw',
#  'dow',
#  'hoce',
#  'www',
#  'hihow',
#  'howqy',
#  'zhowe',
#  'uiow',
#  'mholw',
#  'oxow',
#  'heiow',
#  'kfow',
#  'ghokw',
#  'iholw',
#  'bhww',
#  'htv',
#  'hlowi',
#  'huowa',
#  'kowv',
#  'hvouw',
#  'iowd',
#  'hwlw',
#  'jhoyw',
#  'dkw',
#  'hvwx',
#  'hzwq',
#  'hoywh',
#  'hazw',
#  'hloqw',
#  'hmwb',
#  'noj',
#  'hsov',
#  'uhgw',
#  'ykw',
#  'hobh',
#  'hkwd',
#  'fhuow',
#  'hocfw',
#  'hocwu',
#  'dhbow',
#  'lvw',
#  'chowm',
#  'hdwi',
#  'doyw',
#  'hbon',
#  'tzw',
#  'hhtw',
#  'powl',
#  'hogyw',
#  'zhjw',
#  'hokwh',
#  'hgm',
#  'hti',
#  'yhowd',
#  'ohm',
#  'hiozw',
#  'hf',
#  'ihowd',
#  'ihdw',
#  'homb',
#  'losw',
#  'hkl',
#  'azw',
#  'holh',
#  'ldow',
#  'howxr',
#  'hpy',
#  'horyw',
#  'hxoe',
#  'ahpw',
#  'mhew',
#  'showb',
#  'ghlow',
#  'ohnw',
#  'whnow',
#  'sowu',
#  'lhoaw',
#  'hoeu',
#  'howgr',
#  'hbwp',
#  'bhbw',
#  'hgs',
#  'taw',
#  'ghwo',
#  'mkow',
#  'honwl',
#  'hoqwo',
#  'hxiow',
#  'mhbw',
#  'hobv',
#  'hsowj',
#  'ohb',
#  'ihuw',
#  'showz',
#  'eaw',
#  'or',
#  'hok',
#  'hnj',
#  'zhok',
#  'efw',
#  'hi',
#  'ooc',
#  'dehow',
#  'oovw',
#  'wpow',
#  'hylw',
#  'haok',
#  'hmiow',
#  'howez',
#  'vgw',
#  'vhoe',
#  'hokc',
#  'lhodw',
#  'xaw',
#  'kowx',
#  'howyl',
#  'inhow',
#  'nowf',
#  'zhjow',
#  'ihqow',
#  'aww',
#  'nhozw',
#  'ohowx',
#  'honl',
#  'phoq',
#  'lhowg',
#  'hba',
#  'howfv',
#  'sfow',
#  'bcw',
#  'htwm',
#  'hsomw',
#  'ahokw',
#  'haol',
#  'xhowo',
#  'cyhow',
#  'hrod',
#  'owm',
#  'hoei',
#  'qhor',
#  'phowr',
#  'howch',
#  'whoa',
#  'hewl',
#  'hofz',
#  'hynw',
#  'hodf',
#  'hwoxw',
#  'hzowo',
#  'klhow',
#  'hoai',
#  'bdw',
#  'hjzw',
#  'hnot',
#  'ehoa',
#  'joa',
#  'uhoww',
#  'howtd',
#  'vhol',
#  'ypow',
#  'howwe',
#  'hcaw',
#  'howou',
#  'nhowv',
#  'xhox',
#  'hfowd',
#  'hiwe',
#  'hhoiw',
#  'hryow',
#  'htot',
#  'hotv',
#  'holwo',
#  'hhc',
#  'dhqw',
#  'kowz',
#  'phoz',
#  'hiaow',
#  'scw',
#  'zshow',
#  'cohow',
#  'hqwk',
#  'hzbow',
#  'nowi',
#  'hyvw',
#  'hoprw',
#  'hohg',
#  'mhowd',
#  'hnowg',
#  'khop',
#  'iowi',
#  'lowo',
#  'gww',
#  'mowr',
#  'hqozw',
#  'hsg',
#  'xvw',
#  'asow',
#  'hoasw',
#  'hsuw',
#  'howdg',
#  'uor',
#  'hoqwp',
#  'hqowt',
#  'hozww',
#  'hrww',
#  'yhow',
#  'uogw',
#  'shew',
#  'hsb',
#  'rhyow',
#  'hows',
#  'shgw',
#  'hzzow',
#  'hwowy',
#  'tbw',
#  'howfh',
#  'tjow',
#  'hjowb',
#  'hiowc',
#  'cof',
#  'jhsow',
#  'hpowo',
#  'ehon',
#  'zoww',
#  'yuow',
#  'hopwa',
#  'hodwh',
#  'hoyg',
#  'hbtw',
#  'hotyw',
#  'gonw',
#  'xhohw',
#  'hoawb',
#  'yojw',
#  'hiowx',
#  'hwwd',
#  'jonw',
#  'hotaw',
#  'hmwj',
#  'hktw',
#  'hsowg',
#  'hhm',
#  'dhovw',
#  'xhowr',
#  'jhgw',
#  'qovw',
#  'hiwx',
#  'nlhow',
#  'homyw',
#  'xokw',
#  'ohlw',
#  'hwoo',
#  'choz',
#  'yhokw',
#  'howzf',
#  'oyw',
#  'hoth',
#  'hqwl',
#  'qowy',
#  'lhov',
#  'zjw',
#  'hkoy',
#  'ahvow',
#  'qew',
#  'hmoq',
#  'hsv',
#  'eoe',
#  'ohoxw',
#  'nqw',
#  'whjow',
#  'zhew',
#  'xof',
#  'ahobw',
#  'hocww',
#  'hoowu',
#  'hjowi',
#  'htwy',
#  'hjdow',
#  'uhoy',
#  'ohowh',
#  'qhiow',
#  'mor',
#  'fofw',
#  'kog',
#  'oho',
#  'bhbow',
#  'oholw',
#  'whowo',
#  'bhoxw',
#  'howjc',
#  'hoxwn',
#  'hxvow',
#  'hpow',
#  'rhfow',
#  'heoaw',
#  'bhmow',
#  'oqhow',
#  'mhgw',
#  'frhow',
#  'hoob',
#  'khw',
#  'kdhow',
#  'hajw',
#  'choew',
#  'qopw',
#  'ohl',
#  'hrrw',
#  'howkv',
#  'hdyow',
#  'thww',
#  'zew',
#  'uhoj',
#  'hlgow',
#  'qcw',
#  'hyowx',
#  'hofwy',
#  'homd',
#  'hoswo',
#  'hpoqw',
#  'qhowj',
#  'whiow',
#  'yhor',
#  'zhowc',
#  'nhnow',
#  'jhwow',
#  'mnow',
#  'bhoww',
#  'non',
#  'hwoaw',
#  'tocw',
#  'hokwk',
#  'hjwm',
#  'cho',
#  'eovw',
#  'hotwm',
#  'ehokw',
#  'fowm',
#  'hpvow',
#  'cfow',
#  'hxyw',
#  'hokjw',
#  'twhow',
#  'hoywa',
#  'hiowf',
#  'nhomw',
#  'hofd',
#  'dhonw',
#  'hch',
#  'jhob',
#  'xhol',
#  'xhoxw',
#  'tcw',
#  'uokw',
#  'kos',
#  'hraw',
#  'fowp',
#  'lhhw',
#  'voiw',
#  'hzeow',
#  ...}

# %%
def correct_spelling(word, vocabulary, word_probabilities):
    if word in vocabulary:
        print(f"{word} is already correctly spelt")
        return

    suggestions = generate_combinations(word) or generate_all_combinations(word) or [word]
    best_guesses = [w for w in suggestions if w in vocabulary]
    return [(w, word_probabilities[w]) for w in best_guesses]

# %%
correct_spelling('teh',vocabulary,word_probabilities)
# Out:
# [('the', 0.00022789425706472196), ('tehy', 0.00022789425706472196)]

# %%
correct_spelling('achieeve',vocabulary,word_probabilities)
# Out:
# [('achieve', 0.00022789425706472196)]

# %%
correct_spelling('thow',vocabulary,word_probabilities)
# Out:
# [('show', 0.00022789425706472196)]
